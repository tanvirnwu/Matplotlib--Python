# %% [markdown]
# # Plotting Live Data in Real-Time

# %%
import random
from itertools import count
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

# %%
plt.style.use('seaborn')

# %%
x_vals = [0, 1, 2, 3, 4, 5]
y_vals = [0, 1, 3, 2, 3, 5]

plt.plot(x_vals, y_vals)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
x_vals = []
y_vals = []

index = count()

def animatee(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(0, 10))
    
    plt.cla()
    plt.plot(x_vals, y_vals)

anim = FuncAnimation(plt.gcf(), animatee, interval=1000)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
()
