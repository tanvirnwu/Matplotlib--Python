# %% [markdown]
# # Scatter Plots
# - Matplotlib Marker Styles - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
# - Matplotlib Colormaps - https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
plt.style.use('seaborn')
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

# %%
plt.scatter(x,y, s=55, c='green', marker='o',
           edgecolor='red', linewidth=1, alpha=0.7)

# %%
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
plt.scatter(x,y, s=100, c=colors, cmap='coolwarm', marker='o',
           edgecolor='black', linewidth=1, alpha=0.7)

# %%
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
plt.scatter(x,y, s=50, c=colors, cmap='seismic', marker='o',
           edgecolor='black', linewidth=1, alpha=0.7)

cbar=plt.colorbar()
cbar.set_label('Satisfaction')

# %%
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174, 538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]
plt.scatter(x,y, s=sizes, c=colors, cmap='inferno', marker='o',
           edgecolor='white', linewidth=1, alpha=0.75)

cbar=plt.colorbar()
cbar.set_label('Satisfaction')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Matplotlib/07-ScatterPlots/2019-05-31-data.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

# %%
data.head(3)
# Out:
#    view_count   likes  ratio
# 0     8036001  324742  96.91
# 1     9378067  562589  98.19
# 2     2182066  273650  99.38

# %%
plt.scatter(view_count,likes, c= ratio, edgecolor='white', cmap='coolwarm', linewidth=.5, alpha=.7)

cbar=plt.colorbar()
cbar.set_label('Like/Dislike Ratio')
plt.xlabel('views')
plt.ylabel('Likes')
plt.xscale('log')
plt.yscale('log')
